# %%
import pandas as pd
df=pd.read_csv('Car_sales.csv')

# %%
df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
df.head()
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0  Acura          Integra                        16.919               16.36
# 1  Acura          TL                             39.384              19.875
# 2  Acura          CL                             14.114              18.225
# 3  Acura          RL                              8.588              29.725
# 4  Audi           A4                             20.397              22.255
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0    Passenger               21.5         1.8        140     101.2  67.3
# 1    Passenger               28.4         3.2        225     108.1  70.3
# 2    Passenger                  .         3.2        225     106.9  70.6
# 3    Passenger                 42         3.5        210     114.6  71.4
# 4    Passenger              23.99         1.8        150     102.6  68.2
#
#   Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# ...

# %%
df.dtypes
# Out:
# Manufacturer            object
# Model                   object
# Sales in thousands     float64
# 4-year resale value     object
# Vehicle type            object
# Price in thousands      object
# Engine size             object
# Horsepower              object
# Wheelbase               object
# Width                   object
# Length                  object
# Curb weight             object
# Fuel capacity           object
# Fuel efficiency         object
# Latest Launch           object
# dtype: object

# %%
df.shape
# Out:
# (157, 15)

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (157, 15)

# %%
df.describe()
# Out:
#        Sales in thousands
# count          157.000000
# mean            52.998076
# std             68.029422
# min              0.110000
# 25%             14.114000
# 50%             29.450000
# 75%             67.956000
# max            540.561000

# %%
df.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Sales in thousands     0
# 4-year resale value    0
# Vehicle type           0
# Price in thousands     0
# Engine size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb weight            0
# Fuel capacity          0
# Fuel efficiency        0
# Latest Launch          0
# dtype: int64

# %%
df.isnull().sum().idxmax()
# Out:
# 'Manufacturer'

# %%
df.drop(columns=['Manufacturer'])
# Out:
#                  Model  Sales in thousands 4-year resale value Vehicle type  \
# 0    Integra                        16.919               16.36    Passenger
# 1    TL                             39.384              19.875    Passenger
# 2    CL                             14.114              18.225    Passenger
# 3    RL                              8.588              29.725    Passenger
# 4    A4                             20.397              22.255    Passenger
# ..                 ...                 ...                 ...          ...
# 152  V40                             3.545                   .    Passenger
# 153  S70                            15.245                   .    Passenger
# 154  V70                            17.531                   .    Passenger
# 155  C70                             3.493                   .    Passenger
# 156  S80                            18.969                   .    Passenger
#
# ...

# %%
categorical_cols=df.select_dtypes(include=['object','category']).columns

# %%
clean=df.dropna(subset=categorical_cols)
print(clean)
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
#drop the categorical missing values
categorical_values=df.select_dtypes(include=['object','category']).columns
clean=df.dropna(subset=categorical_values)
print(clean)
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
#import the rows with numerical missing values
numeric_cols=df.select_dtypes(include=['number']).columns
missing_numeric=df[df[numeric_cols].isnull().any(axis=1)]
missing_numeric
# Out:
# Empty DataFrame
# Columns: [Manufacturer, Model, Sales in thousands, 4-year resale value, Vehicle type, Price in thousands, Engine size, Horsepower, Wheelbase, Width, Length, Curb weight, Fuel capacity, Fuel efficiency, Latest Launch]
# Index: []

# %%
sort=df.sort_values(by='Price in thousands')

# %%
sort
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 2    Acura          CL                             14.114              18.225
# 33   Chrysler       Town & Country                 53.480               19.54
# 129  Saturn         SL                             80.620                 9.2
# 140  Toyota         Tacoma                         84.087               9.575
# 63   Hyundai        Elantra                        66.692               7.825
# ..             ...                ...                 ...                 ...
# 126  Porsche        Carrera Cabriolet               1.866               67.55
# 95   Mercedes-Benz  SL-Class                        3.311                58.6
# 99   Mercedes-Benz  CL500                           0.954                   .
# 26   Chevrolet      Metro                          21.855                5.16
# 62   Hyundai        Accent                         41.184                5.86
#
# ...

# %%
sort.iloc[0]#most expensive
# Out:
# Manufacturer               Acura
# Model                  CL
# Sales in thousands                14.114
# 4-year resale value               18.225
# Vehicle type                   Passenger
# Price in thousands                     .
# Engine size                          3.2
# Horsepower                           225
# Wheelbase                          106.9
# Width                               70.6
# Length                               192
# Curb weight                         3.47
# Fuel capacity                       17.2
# Fuel efficiency                       26
# Latest Launch                   1-Apr-14
# Name: 2, dtype: object

# %%
sort.iloc[-1]
# Out:
# Manufacturer               Hyundai
# Model                  Accent
# Sales in thousands                41.184
# 4-year resale value                 5.86
# Vehicle type                   Passenger
# Price in thousands                 9.699
# Engine size                          1.5
# Horsepower                            92
# Wheelbase                           96.1
# Width                               65.7
# Length                             166.7
# Curb weight                         2.24
# Fuel capacity                       11.9
# Fuel efficiency                       31
# Latest Launch                   9-Oct-14
# Name: 62, dtype: object

# %%
df['Price in thousands']=pd.to_numeric(df['Price in thousands'],errors='coerce')
df['Price in thousands']=df['Price in thousands'].fillna(df['Price in thousands'].mean())
df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
#find min and max
def find_min_max(df,col_name):
    min_value=df[col_name].min()
    max_value=df[col_name].max()
    return min_value,max_value

# %%
min_value,max_value=find_min_max(df,'Price in thousands')
min_value
# Out:
# 9.235

# %%
max_value
# Out:
# 85.5

# %%
df['Horsepower']=pd.to_numeric(df['Horsepower'],errors='coerce')
min_value,max_value=find_min_max(df,'Horsepower')
print(min_value)
# Out:
# 55.0

# %%
max_value
# Out:
# 450.0

# %%
df['Length']=pd.to_numeric(df['Length'],errors='coerce')
min_value,max_value=find_min_max(df,'Length')
min_value
# Out:
# 149.4

# %% [markdown]
# max_value

# %%
max_value
# Out:
# 224.5

# %% [markdown]
# max_value

# %%
df.dtypes
# Out:
# Manufacturer            object
# Model                   object
# Sales in thousands     float64
# 4-year resale value     object
# Vehicle type            object
# Price in thousands     float64
# Engine size             object
# Horsepower             float64
# Wheelbase               object
# Width                   object
# Length                 float64
# Curb weight             object
# Fuel capacity           object
# Fuel efficiency         object
# Latest Launch           object
# dtype: object

# %%
df['Fuel efficiency']=pd.to_numeric(df['Fuel efficiency'],errors='coerce')
min_value,max_value=find_min_max(df,'Fuel efficiency')

# %%
min_value
# Out:
# 15.0

# %% [markdown]
# max_value

# %%
max_value
# Out:
# 45.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cols=['Price in thousands','Sales in thousands	','Horsepower','Fuel efficiency']
for col in cols:
    plt.figure(figsize=(8,5))
    sns.histplot(x=col,data=df,kde=True)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-266-2e53e658dabe> in <module>
#       2 for col in cols:
#       3     plt.figure(figsize=(8,5))
# ----> 4     sns.histplot(x=col,data=df,kde=True)
#       5     plt.show()
#
# ~/.local/lib/python3.8/site-packages/seaborn/distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1377 ):
#    1378
# -> 1379     p = _DistributionPlotter(
#    1380         data=data,
#    1381         variables=dict(x=x, y=y, hue=hue, weights=weights),
#
# ~/.local/lib/python3.8/site-packages/seaborn/distributions.py in __init__(self, data, variables)
#     108     ):
#     109
# ...

# %%
continuous=df[["Price in thousands","Sales in thousands","Horsepower","Fuel efficiency"]]

# %%
sns.histplot(continuous)
# Out:
# <Axes: ylabel='Count'>

# %%
df['Length']=pd.to_numeric(df['Length'],errors='coerce')
df=df.dropna(subset=['Length'])

# %%
sns.kdeplot(df['Length'],fill=True)
plt.title("density of length")
plt.xlabel('Length')
plt.ylabel('Density')
plt.show()

# %%
print(df['Manufacturer'].value_counts())
# Out:
# Manufacturer
# Dodge            11
# Ford             11
# Toyota            9
# Chevrolet         9
# Mercedes-Benz     9
# Mitsubishi        7
# Nissan            7
# Volvo             6
# Pontiac           6
# Lexus             6
# Oldsmobile        6
# Mercury           6
# Chrysler          6
# Volkswagen        6
# Saturn            5
# Cadillac          5
# Honda             5
# Plymouth          4
# Acura             4
# Buick             4
# Audi              3
# Jeep              3
# Porsche           3
# Hyundai           3
# BMW               3
# Lincoln           3
# Saab              2
# Subaru            2
# Jaguar            1
# Infiniti          1
# Name: count, dtype: int64

# %%
numeric_cols=df.select_dtypes(include=['number'])
numeric_cols
# Out:
#      Sales in thousands  Price in thousands  Horsepower  Length  \
# 0                16.919           21.500000       140.0   172.4
# 1                39.384           28.400000       225.0   192.9
# 2                14.114           27.390755       225.0   192.0
# 3                 8.588           42.000000       210.0   196.6
# 4                20.397           23.990000       150.0   178.0
# ..                  ...                 ...         ...     ...
# 152               3.545           24.400000       160.0   176.6
# 153              15.245           27.500000       168.0   185.9
# 154              17.531           28.800000       168.0   186.2
# 155               3.493           45.500000       236.0   185.7
# 156              18.969           36.000000       201.0   189.8
#
#      Fuel efficiency
# 0               28.0
# 1               25.0
# 2               26.0
# 3               22.0
# 4               27.0
# ..               ...
# 152             25.0
# ...

# %%
df['Price in thousands']=pd.to_numeric(df['Price in thousands'],errors='coerce')
print(df['Price in thousands'].corr(df['Sales in thousands']))
# Out:
# -0.30441318425711283
# <ipython-input-273-f93e08aa9341>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price in thousands']=pd.to_numeric(df['Price in thousands'],errors='coerce')

# %%
sns.scatterplot(x='Price in thousands',y='Sales in thousands',data=df)
plt.show()

# %%
sns.pairplot(df)

# %%
sns.boxplot(x='Price in thousands',y='Sales in thousands',data=df)
plt.show()

# %%
for col in df.select_dtypes(include=['number']).columns:
    sns.boxplot(x='Manufacturer',y=col,data=df)
    plt.show()

# %%
y=df['Sales in thousands']
x=df.drop(columns=['Sales in thousands'])

# %% [markdown]
# df.columns.tolist()

# %%
df.columns.tolist()
# Out:
# ['Manufacturer',
#  'Model',
#  'Sales in thousands',
#  '4-year resale value',
#  'Vehicle type',
#  'Price in thousands',
#  'Engine size',
#  'Horsepower',
#  'Wheelbase',
#  'Width',
#  'Length',
#  'Curb weight',
#  'Fuel capacity',
#  'Fuel efficiency',
#  'Latest Launch']

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder,StandardScaler
categorical=df.select_dtypes(include=['object']).columns.tolist()
le=LabelEncoder()
for col in categorical:
    df[col]=le.fit_transform(df[col])
df
# Out:
# <ipython-input-280-adef6f2fc014>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col]=le.fit_transform(df[col])
# <ipython-input-280-adef6f2fc014>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col]=le.fit_transform(df[col])
# <ipython-input-280-adef6f2fc014>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
y=df['Sales in thousands']
x=df.drop(columns=['Sales in thousands'])
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=42)

# %%
x
# Out:
#      Manufacturer  Model  4-year resale value  Vehicle type  \
# 0               0     79                   53             1
# 1               0    143                   69             1
# 2               0     25                   63             1
# 3               0    115                   86             1
# 4               1      8                   77             1
# ..            ...    ...                  ...           ...
# 152            29    147                    0             1
# 153            29    125                    0             1
# 154            29    148                    0             1
# 155            29     24                    0             1
# 156            29    126                    0             1
#
#      Price in thousands  Engine size  Horsepower  Wheelbase  Width  Length  \
# 0             21.500000            3       140.0          4      8   172.4
# 1             28.400000           15       225.0         35     31   192.9
# ...

# %%
x.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# 4-year resale value    0
# Vehicle type           0
# Price in thousands     0
# Engine size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb weight            0
# Fuel capacity          0
# Fuel efficiency        2
# Latest Launch          0
# dtype: int64

# %%
x['Fuel efficiency']=x['Fuel efficiency'].fillna(x['Fuel efficiency'].mean())

# %%
x
# Out:
#      Manufacturer  Model  4-year resale value  Vehicle type  \
# 0               0     79                   53             1
# 1               0    143                   69             1
# 2               0     25                   63             1
# 3               0    115                   86             1
# 4               1      8                   77             1
# ..            ...    ...                  ...           ...
# 152            29    147                    0             1
# 153            29    125                    0             1
# 154            29    148                    0             1
# 155            29     24                    0             1
# 156            29    126                    0             1
#
#      Price in thousands  Engine size  Horsepower  Wheelbase  Width  Length  \
# 0             21.500000            3       140.0          4      8   172.4
# 1             28.400000           15       225.0         35     31   192.9
# ...

# %%
x.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# 4-year resale value    0
# Vehicle type           0
# Price in thousands     0
# Engine size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb weight            0
# Fuel capacity          0
# Fuel efficiency        0
# Latest Launch          0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=42)
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([-44.35350118,  29.81028167,  61.92061144,  43.088341  ,
#         80.95297074,  36.85052567, -82.59853999,  79.63121456,
#         -4.1352588 ,  93.25492898,  79.83693147,  76.71330832,
#        152.15934767, -22.08123351,  38.90607998,  91.77599773])

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))
# Out:
# -1.3862007331795927
