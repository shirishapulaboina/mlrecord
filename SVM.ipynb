# %%
import pandas as pd
df=pd.read_csv('Week8_Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.shape
# Out:
# (150, 6)

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.columns.unique()
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
df=df.drop(columns=['Id'])

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cols=df.drop(columns=['Species'])

# %%
for col in cols:
    plt.figure(figsize=(8,5))
    sns.histplot(x=col,data=df,kde=True)
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x=df['SepalLengthCm'],y=df['SepalWidthCm'],hue=df['Species'],palette='pastel')
plt.xlabel('SepalLengthCm')
plt.ylabel('SepalwidthCm')
plt.show()

# %%
g=sns.FacetGrid(df,col='Species',height=4,aspect=1)
g.map(sns.scatterplot,'SepalLengthCm','SepalWidthCm',color='green')
g.set_axis_labels('Sepal Length (cm)','Sepal width (cm)')
g.fig.suptitle('sepal dimesnions by species',y=1.05)
plt.show()

# %%
sns.boxplot(x='Species',y='PetalWidthCm',data=df)
plt.show()

# %%
sns.boxplot(x='Species',y='PetalLengthCm',data=df)
# Out:
# <Axes: xlabel='Species', ylabel='PetalLengthCm'>

# %%
sns.pairplot(df,hue='Species',palette='pastel',diag_kind=True)

# %%
sns.pairplot(df,hue='Species',palette='pastel')

# %%
df['SepalLengthCm'].corr(df['SepalWidthCm'])
# Out:
# -0.10936924995064937

# %%
x=df.drop(columns='Species')
y=df['Species']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
from sklearn.svm import SVC
model=SVC(kernel='linear',C=1)
model.fit(x_train,y_train)
# Out:
# SVC(C=1, kernel='linear')

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-setosa', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor'], dtype=object)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
classification_report(y_test,y_pred)
# Out:
# '                 precision    recall  f1-score   support\n\n    Iris-setosa       1.00      1.00      1.00        14\nIris-versicolor       1.00      1.00      1.00        18\n Iris-virginica       1.00      1.00      1.00        13\n\n       accuracy                           1.00        45\n      macro avg       1.00      1.00      1.00        45\n   weighted avg       1.00      1.00      1.00        45\n'

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[14,  0,  0],
#        [ 0, 18,  0],
#        [ 0,  0, 13]])

# %%
cm=confusion_matrix(y_test,y_pred)
sns.heatmap(cm,xticklabels=["Iris-setosa","Iris-versicolor","Iris-virginica"],yticklabels=["Iris-setosa","Iris-versicolor","Iris-virginica"],fmt="d",annot=True,cmap='YlGnBu')
# Out:
# <Axes: >

# %%
from sklearn.model_selection import KFold,cross_val_score
model=SVC(kernel='linear',C=1)
kf=KFold(n_splits=5,shuffle=True,random_state=42)
scores=cross_val_score(model,x,y,cv=kf)
print(scores)
# Out:
# [1.         1.         0.96666667 0.93333333 0.96666667]

# %%
import numpy as np
np.mean(scores)
# Out:
# 0.9733333333333334
